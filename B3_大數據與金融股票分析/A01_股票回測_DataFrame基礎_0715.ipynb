# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandwhaletree/Mai_Finlab/blob/main/%E5%A4%A7%E6%95%B8%E6%93%9A%E8%88%87%E9%87%91%E8%9E%8D%E8%82%A1%E7%A5%A8%E5%88%86%E6%9E%90/A01_%E8%82%A1%E7%A5%A8%E5%9B%9E%E6%B8%AC_DataFrame%E5%9F%BA%E7%A4%8E_0715.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# 定義list
a=[ [1,2,3],[2,3,4],[3,4,5] ]
# 從list 轉換成dataframe 的方法
pd.DataFrame(a)
# Out:
#    0  1  2
# 0  1  2  3
# 1  2  3  4
# 2  3  4  5

# %%
# 定義dictionary
b={    'open':[1,2,3],
       'high':[7,8,9],
       'close' :[3,4,5]}
# 從dictionary 轉換為dataframe 的方法
pd.DataFrame(b)
# Out:
#    open  high  close
# 0     1     7      3
# 1     2     8      4
# 2     3     9      5

# %%
# 組成函示庫
# function
# class
# 1- 屬性 (variable)
# 2- 方法 (function)

# %%
# 查看dataframe 屬性
a=pd.DataFrame(b)
a.ndim # 維度
a.shape # 面積
a.dtypes # 資料型態
# Out:
# open     int64
# high     int64
# close    int64
# dtype: object

# %%
# 取得行數
a.shape[0]
# Out:
# 3

# %%
# 如何呼叫欄位
a['open'] #老師習慣這種方法，因為有時候欄位是中文，用a.open感覺怪怪的
a.open
# Out:
# 0    1
# 1    2
# 2    3
# Name: open, dtype: int64

# %%
# 針對指定行數 去新增欄位
a['low']=[0,1,2] #資料筆數與原資料是一樣的
a
# Out:
#    open  high  close  low
# 0     1     7      3    0
# 1     2     8      4    1
# 2     3     9      5    2

# %%
# 直接將新欄位調整成統一值
a['volume']= 100
a
# Out:
#    open  high  close  low  volume
# 0     1     7      3    0     100
# 1     2     8      4    1     100
# 2     3     9      5    2     100

# %% [markdown]
# #### loc (locate)

# %%
# 如何取用資料-loc # locate
# a.loc[行,列] # 用欄位名稱來取得指定資料的方法
a.loc[1,'low']
# Out:
# 1

# %%
#牛刀小試：抓到2的行 close的值
a.loc[2,'close']
# Out:
# 5

# %%
# 抓到1,2兩行
a.loc[1:2,'open']
# Out:
# 1    2
# 2    3
# Name: open, dtype: int64

# %%
# 抓到值為1以後的行的值
a.loc[1:,'open']
# Out:
# 1    2
# 2    3
# Name: open, dtype: int64

# %%
#抓幾行的最高價
max(a.loc[1:2,'high'])
# Out:
# 9

# %% [markdown]
# #### iloc(index locate)

# %%
# 如何取用資料-iloc # index locate
# 是用欄位索引來取得指定資料的方法
a.iloc[2,3] # 實際上取得low的值
# Out:
# 2

# %%
# df的行索引
a.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# df的欄位索引
a.columns
# Out:
# Index(['open', 'high', 'close', 'low', 'volume'], dtype='object')

# %%
#列表推導式
[ i for i in a.index ]
# Out:
# [0, 1, 2]

# %%
#tmplist=[1,2,3]
#[ i for i in tmplist ]
#  ^     ^       ^
#運算式
#      迴圈變數 目標的集合

#[ 1, 2, 3 ] <- 集合
#(元素)
[ i for i in range(1,10) ]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# dataframe 篩選資料
a[ a['high'] > 7 ]
# Out:
#    open  high  close  low  volume
# 1     2     8      4    1     100
# 2     3     9      5    2     100

# %%
# 取得 not 的條件判斷
a[ ~(a['high'] > 7) ]
# Out:
#    open  high  close  low  volume
# 0     1     7      3    0     100

# %%
# 複合判斷式
a[ (a['high'] > 7)&(a['open'] > 2) ]
# Out:
#    open  high  close  low  volume
# 2     3     9      5    2     100

# %% [markdown]
# ### 改變路徑&讀取檔案

# %%
# 存檔讀檔
# 改變工作路徑[spyder]
import os
# os.chdir('C:\\Users\\jack\\Desktop\\生產力_課程筆記') #改變工作路徑
# os.chdir('C:\\Users\\USER\\OneDrive\\0_2023文件資料\\10_class_william_python stock\\課堂-生產力-202206')

# %%
#儲存csv檔案-含有原index
a.to_csv('範例dataframe.csv')
df=pd.read_csv('範例dataframe.csv')
df
# Out:
#    Unnamed: 0  open  high  close  low  volume
# 0           0     1     7      3    0     100
# 1           1     2     8      4    1     100
# 2           2     3     9      5    2     100

# %%
#儲存csv檔案-沒有原index->常用
a.to_csv('範例dataframe2.csv',index=False)
df=pd.read_csv('範例dataframe2.csv')
df
# Out:
#    open  high  close  low  volume
# 0     1     7      3    0     100
# 1     2     8      4    1     100
# 2     3     9      5    2     100

# %%
#儲存csv檔案-不儲存欄位名稱
a.to_csv('範例dataframe3.csv',
         index=False,
         header=False)
df=pd.read_csv('範例dataframe3.csv')
df
# Out:
#    1  7  3  0  100
# 0  2  8  4  1  100
# 1  3  9  5  2  100

# %%
#儲存csv檔案-欄位為中文名，csv下載打開會有中文亂碼
a['漲跌'] = 0
a.to_csv('範例dataframe4.csv')
df=pd.read_csv('範例dataframe4.csv')
df
# Out:
#    Unnamed: 0  open  high  close  low  volume  漲跌
# 0           0     1     7      3    0     100   0
# 1           1     2     8      4    1     100   0
# 2           2     3     9      5    2     100   0

# %%
#儲存csv檔案-欄位為中文名，csv下載打開會有中文亂碼->解決: windows編碼 cp950；mac編碼 utf-8
a['漲跌'] = 0
# a.to_csv('範例dataframe4-1.csv',encoding='cp950') #spyder環境下
a.to_csv('範例dataframe4-1.csv',encoding='utf-8')
df=pd.read_csv('範例dataframe4-1.csv')
df
# Out:
#    Unnamed: 0  open  high  close  low  volume  漲跌
# 0           0     1     7      3    0     100   0
# 1           1     2     8      4    1     100   0
# 2           2     3     9      5    2     100   0

# %%
#取多欄位表格
a['ma']=0
a[ ['open','ma'] ]
# Out:
#    open  ma
# 0     1   0
# 1     2   0
# 2     3   0

# %%
#欄位自行重新排序
#a.columns
a[ ['open', 'high', 'ma', '漲跌' , 'close', 'low',
    'volume'] ].to_csv('範例dataframe5.csv',encoding='utf-8')
df=pd.read_csv('範例dataframe5.csv',encoding='utf-8')
df
# Out:
#    Unnamed: 0  open  high  ma  漲跌  close  low  volume
# 0           0     1     7   0   0      3    0     100
# 1           1     2     8   0   0      4    1     100
# 2           2     3     9   0   0      5    2     100

# %% [markdown]
# ### API套件-公開資料免費
# * yfinance - 國外股市資訊豐富
# * finmind - 國內的金融商品公開資訊

# %%
# !pip install yfinance

# %%
import yfinance as yf
data=yf.Ticker('BABA') #台灣股票 #'0050.TW'
data
# Out:
# yfinance.Ticker object <BABA>

# %%
data.info #data的屬性
# Out:
# {'address1': '969 West Wen Yi Road',
#  'address2': 'Yu Hang District',
#  'city': 'Hangzhou',
#  'zip': '311121',
#  'country': 'China',
#  'phone': '86 571 8502 2088',
#  'fax': '86 571 8376 8429',
#  'website': 'https://www.alibabagroup.com',
#  'industry': 'Internet Retail',
#  'industryDisp': 'Internet Retail',
#  'sector': 'Consumer Cyclical',
# ...

# %%
data2=data.financials # 連續四年損益表
data2
# Out:
#                                                         2023-03-31  \
# Tax Effect Of Unusual Items                           -461380000.0
# Tax Rate For Calcs                                            0.17
# Normalized EBITDA                                   122392000000.0
# Total Unusual Items                                  -2714000000.0
# Total Unusual Items Excluding Goodwill               -2714000000.0
# Net Income From Continuing Operation Net Minori...   72783000000.0
# Reconciled Depreciation                              13504000000.0
# Reconciled Cost Of Revenue                          549695000000.0
# EBIT                                                106174000000.0
# Net Interest Income                                 -16989000000.0
# Interest Expense                                     16989000000.0
# Interest Income                                                NaN
# Normalized Income                                    75035620000.0
# ...

# %%
#作者尚未將功能建立好
# data.earnings

# %%
data4=data.actions
data4
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
data.history() # 取得歷史資料
# Out:
#                                 Open        High        Low       Close  \
# Date
# 2023-06-29 00:00:00-04:00  83.389999   83.989998  83.000000   83.550003
# 2023-06-30 00:00:00-04:00  83.230003   84.230003  83.010002   83.349998
# 2023-07-03 00:00:00-04:00  84.870003   85.635002  84.000000   84.070000
# 2023-07-05 00:00:00-04:00  83.980003   84.690002  82.820000   84.300003
# 2023-07-06 00:00:00-04:00  83.120003   83.949997  82.639999   83.839996
# 2023-07-07 00:00:00-04:00  86.760002   91.570000  86.629997   90.550003
# 2023-07-10 00:00:00-04:00  90.050003   92.040001  89.599998   90.559998
# 2023-07-11 00:00:00-04:00  91.019997   92.320000  89.010002   91.790001
# 2023-07-12 00:00:00-04:00  94.110001   95.029999  92.550003   94.000000
# 2023-07-13 00:00:00-04:00  95.029999   97.004997  94.599998   96.610001
# 2023-07-14 00:00:00-04:00  95.220001   96.089996  94.239998   94.559998
# 2023-07-17 00:00:00-04:00  92.250000   93.550003  91.040001   93.410004
# ...

# %%
# 透過yahoo finance 去下載股票日頻率資料
data=yf.download('BABA',
                 start = '2022-01-1',
                 end ='2022-07-15' )
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  119.379997  121.949997  115.820000  120.379997  120.379997
# 2022-01-04  119.529999  120.870003  115.769997  119.559998  119.559998
# 2022-01-05  118.000000  126.620003  117.699997  121.160004  121.160004
# 2022-01-06  124.260002  128.399994  123.464996  126.629997  126.629997
# 2022-01-07  130.240005  133.880005  128.179993  129.809998  129.809998
# ...                ...         ...         ...         ...         ...
# 2022-07-08  122.260002  125.839996  120.699997  120.900002  120.900002
# 2022-07-11  115.459999  115.580002  109.330002  109.570000  109.570000
# 2022-07-12  110.860001  111.000000  107.059998  109.209999  109.209999
# 2022-07-13  106.839996  110.639999  106.750000  109.099998  109.099998
# 2022-07-14  107.800003  108.540001  100.709999  103.760002  103.760002
#
#               Volume
# Date
# ...

# %%
data=yf.download('0050.TW',
                 start = '2022-01-1',
                 end ='2022-07-15' )
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  146.000000  147.350006  146.000000  146.399994  146.399994
# 2022-01-04  147.699997  149.600006  147.699997  149.600006  149.600006
# 2022-01-05  150.100006  150.550003  149.100006  149.300003  149.300003
# 2022-01-06  148.300003  148.750000  147.000000  147.899994  147.899994
# 2022-01-07  148.300003  149.000000  146.500000  146.600006  146.600006
# ...                ...         ...         ...         ...         ...
# 2022-07-08  113.300003  113.900002  112.300003  113.250000  113.250000
# 2022-07-11  113.650002  113.699997  111.849998  112.250000  112.250000
# 2022-07-12  110.949997  110.949997  109.150002  109.550003  109.550003
# 2022-07-13  113.000000  113.650002  112.599998  113.449997  113.449997
# 2022-07-14  112.699997  114.250000  111.800003  114.000000  114.000000
#
#               Volume
# Date
# ...

# %%
#僅7天不構成歷史回測時間長度，故不使用下方時間區間
data=yf.download('0050.TW',
                 period = '7d',
                 interval= '1m')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-07-20 09:00:00+08:00  129.050003  129.149994  129.050003  129.100006
# 2023-07-20 09:01:00+08:00  129.100006  129.100006  129.050003  129.050003
# 2023-07-20 09:02:00+08:00  129.050003  129.100006  129.050003  129.050003
# 2023-07-20 09:03:00+08:00  129.050003  129.149994  129.000000  129.149994
# 2023-07-20 09:04:00+08:00  129.149994  129.199997  129.149994  129.199997
# ...                               ...         ...         ...         ...
# 2023-07-28 13:20:00+08:00  129.350006  129.350006  129.350006  129.350006
# 2023-07-28 13:21:00+08:00  129.350006  129.350006  129.350006  129.350006
# 2023-07-28 13:22:00+08:00  129.350006  129.350006  129.350006  129.350006
# 2023-07-28 13:23:00+08:00  129.350006  129.350006  129.350006  129.350006
# 2023-07-28 13:24:00+08:00  129.399994  129.399994  129.350006  129.399994
#
# ...

# %%
#下載周資料 月資料
data=yf.download('0050.TW',
                 start = '2022-01-1',
                 end ='2022-07-15' ,
                 interval='1wk')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  146.000000  150.550003  146.000000  146.600006  146.600006
# 2022-01-10  146.000000  151.199997  145.399994  150.300003  150.300003
# 2022-01-17  151.100006  152.399994  142.300003  142.649994  142.649994
# 2022-01-24  142.100006  144.000000  141.050003  141.550003  141.550003
# 2022-01-31  141.550003  141.550003  141.550003  141.550003  141.550003
# 2022-02-07  142.600006  145.050003  141.199997  144.949997  144.949997
# 2022-02-14  143.949997  145.000000  141.949997  144.100006  144.100006
# 2022-02-21  143.449997  143.850006  137.850006  138.500000  138.500000
# 2022-02-28  138.500000  140.800003  137.949997  138.449997  138.449997
# 2022-03-07  136.899994  136.899994  131.000000  134.399994  134.399994
# 2022-03-14  135.000000  136.600006  131.100006  136.100006  136.100006
# ...

# %% [markdown]
# #### 將取資料寫成函數 Data.py

# %%
# 將取資料寫成函數 Data.py
import yfinance as yf
import pandas as pd
import os

#定義變數
#prod='0050.TW'
#starday='2022-01-1'
#endday='2022-07-15'

def getDataYF(prod,starday,endday):
    #定義存檔名稱
    backup_file='data\\YF_%s_%s_%s.csv'%(prod,starday,endday)

    #第一步:确認是否有本地端檔案
    if not os.path.exists(backup_file):
        #如果沒有我就跟之後寫
        data=yf.download(prod,start = starday, end =endday)
        data.to_csv(backup_file)
        print(f'新增{backup_file}檔案')

    #如果有我就用本地端檔案即可
    else:
        data=pd.read_csv(backup_file)
        #檔案取得後，須將時間改成索引
        data=data.set_index('Date')
        print(f'本地端已有{backup_file}檔案')
    return data

#df=getDataYF(prod,starday,endday)

# %%
# 時間的處理
import datetime

# 取得 '2022-01-01' 的後面 10天的日期 **
# 字串轉時間 時間+10天 時間轉回去字串
# 字串轉時間
sd='2022-01-01'
sd1=datetime.datetime.strptime(sd,'%Y-%m-%d')
sd1
# Out:
# datetime.datetime(2022, 1, 1, 0, 0)

# %%
# %Y YYYY %m mm %d dd
# 時間轉字串
sd1.strftime('%Y%m%d')
# Out:
# '20220101'

# %%
# 時間的運算 timedelta(日,秒)
sd1+datetime.timedelta(10)
sd1-datetime.timedelta(10)
# Out:
# datetime.datetime(2021, 12, 22, 0, 0)

# %%
#日期轉字串
( sd1+datetime.timedelta(10) ).strftime('%Y%m%d')
# Out:
# '20220111'

# %%
#加秒數
sd1+datetime.timedelta(10,10)
# Out:
# datetime.datetime(2022, 1, 11, 0, 0, 10)

# %%
# 時間的判斷
sd2=sd1+datetime.timedelta(10)
sd1 > sd2
sd1 < sd2
# Out:
# True

# %% [markdown]
# #### finmind
# * https://finmind.github.io/
#   * 台灣還原股價資料表 TaiwanStockPriceAdj
# * https://finmindtrade.com/
