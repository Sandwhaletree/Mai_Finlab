# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandwhaletree/Mai_Finlab/blob/main/A_%E7%94%9F%E6%B4%BB%E6%87%89%E7%94%A8/F1_WordCloud_230919.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🔥🔥🔥製作文字雲** #

# %% [markdown]
# ### **👉1.簡易版-英文文字雲** ###
# > #### **✍修改下方"修改1"即可跑程式✍** ####
# * #### [CNN網站](https://edition.cnn.com/) ####
# >#### 將上述網站文字，全部複製貼到"記事本"內儲存成txt檔，並將檔案上傳至google colab:content文件夾，即為下方範例"cnn_20221122.txt" ####
# > * [文字雲參考網站](https://tech.havocfuture.tw/blog/python-wordcloud-jieba)

# %%
#1-1 匯入文字雲套件
from wordcloud import WordCloud, STOPWORDS #文字雲套件-WordCloud
import matplotlib.pyplot as plt

# %%
# Read the whole text.
txtfile = "cnn_20221122.txt" #上傳cnn_20221122.txt檔案至content資料夾 #修改1
text = open(txtfile,"r",encoding="utf-8").read()

# %%
# Generate a word cloud image
wordcloud = WordCloud(width = 5000, height = 3000,).generate(text)

# %%
# 文字雲繪圖
plt.figure(figsize=(10,30))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud.to_file('output1.png') #儲存檔案

# %% [markdown]
# ### **👉2.進階版-英文文字雲:有底圖** ###

# %%
#匯入必要套件
from wordcloud import WordCloud, STOPWORDS
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Read the whole text.
txtfile = "cnn_20221122.txt"  #上傳cnn_20221122.txt檔案至content資料夾 #修改1
pngfile = "football_3.png"  # 上傳底圖.png檔案至content資料夾 #圖片推薦網 https://www.flaticon.com/ #修改2
text = open(txtfile,"r",encoding="utf-8").read()
alice_mask = np.array(Image.open(pngfile))

# Generate a word cloud image
wordcloud = WordCloud(width = 5000, height = 3000,background_color="white", mask=alice_mask, contour_width=3, contour_color='steelblue',max_font_size=300,min_font_size=10,colormap = "Set1").generate(text) #初步生成文字雲

# 繪圖
plt.figure(figsize=(25,15))
plt.imshow(wordcloud, interpolation="bilinear") #文字雲用圖片顯現 #interpolation="bilinear"圖片印出來畫素比較好的必需品
plt.axis("off")
plt.show()

#儲存檔案
wordcloud.to_file('output2.png') #儲存檔案

# %% [markdown]
# ### **👉3.進階版-中文版文字雲** ###
# > #### **✍修改下方"修改1~修改5"即可跑程式✍** ####
# >* ### [修改1.下載Dict字典](https://raw.githubusercontent.com/ldkrsi/jieba-zh_TW/master/jieba/dict.txt) ###
# >#### 將上述網站文字，全部複製貼到"記事本"內儲存成txt檔，並將檔案上傳至google colab:content文件夾，即為下方範例"dict.txt" ####
# * ### [修改2.下載Stopwords](https://github.com/kdchang/python-jieba-chart/blob/master/stopwords.txt) ###
# >#### 將上述網站文字，全部複製貼到"記事本"內儲存成txt檔，並將檔案上傳至google colab:content文件夾，即為下方範例"stopwords.txt"" ####
# * ### 修改3.複製繁體中文msjh.ttc字型  ###
# >#### 本機路徑尋找: C:/Windows/Fonts/微軟正黑體 > 複製"微軟正黑體"字型貼在桌面檔案即是下方範例"msjh.ttc"" ####
# * ### 修改4.找一篇文章儲存txt檔  ###
# >#### 將網站文字，全部複製貼到"記事本"內儲存成txt檔，並將檔案上傳至google colab:content文件夾，即為下方範例"news.txt" ####
# * ### 修改5.找一個圖檔儲存(png/jpg皆可)  ###
# >#### 將圖片下載儲存，並將檔案上傳至google colab:content文件夾，即為下方範例"football_3.png"(*注意檔案格式需一致) ####
# > * [文字雲參考網站](https://tech.havocfuture.tw/blog/python-wordcloud-jieba)

# %%
#匯入必要套件
from wordcloud import WordCloud, STOPWORDS
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import jieba
import jieba.analyse
from collections import Counter # 次數統計

#確保目前的路徑
import os
os.chdir('/content/drive/MyDrive/colab_cloud/wordcloud')

#匯入相關中文字典檔
dictfile = "dict.txt"  # 上傳dict.txt字典檔  #修改1
stopfile = "stopwords.txt"  # 上傳stopwordstxt檔  #修改2
fontpath = "msjh.ttc"  # 上傳繁體中文字型檔 #修改3

mdfile = "words.txt"  # 上傳主要中文文檔chinesewords.txt #修改4
pngfile = "brain.png"  # 剛才下載存的底圖 #修改5

alice_mask = np.array(Image.open(pngfile))

jieba.set_dictionary(dictfile)
jieba.analyse.set_stop_words(stopfile)

text = open(mdfile,"r",encoding="utf-8").read()

tags = jieba.analyse.extract_tags(text, topK=25)

seg_list = jieba.lcut(text, cut_all=False)
dictionary = Counter(seg_list)

freq = {}
for ele in dictionary:
    if ele in tags:
        freq[ele] = dictionary[ele]
print(freq) # 計算出現的次數

#繪圖
wordcloud = WordCloud(width = 4000, height = 3000,background_color="white", mask=alice_mask, contour_width=3, contour_color='steelblue', font_path= fontpath,max_font_size=300,min_font_size=10,colormap = "Set2").generate_from_frequencies(freq)
plt.figure(figsize=(25,15))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

import datetime
#儲存檔案
date = str(datetime.date.today())
wordcloud.to_file(date+'_output.png')
# Out:
# Building prefix dict from /content/drive/MyDrive/colab_cloud/wordcloud/dict.txt ...
# DEBUG:jieba:Building prefix dict from /content/drive/MyDrive/colab_cloud/wordcloud/dict.txt ...
# Dumping model to file cache /tmp/jieba.u9d27e88e7b2fe16e4818e8441943dec4.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.u9d27e88e7b2fe16e4818e8441943dec4.cache
# Loading model cost 1.140 seconds.
# DEBUG:jieba:Loading model cost 1.140 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.
# {'數據': 222, '軟體': 67, '工程師': 645, '應用': 33, '資深': 71, 'Data': 91, 'Engineer': 121, '數位': 47, '大數據': 55, '分析': 74, '資料': 141, 'AI': 48, '開發': 59, '數數': 27, '行銷': 29, '專員': 53, '研發': 44, '專案': 49, '後端': 35, '人員': 44, '產品': 95, '經理': 62, '系統': 30, '助理': 55, 'Manager': 29}

# %%
import os
os.getcwd()
os.chdir('/content/drive/MyDrive/colab_could/wordcould')
